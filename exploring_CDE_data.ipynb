# %%
import pandas as pd
import requests
from io import StringIO

url = "https://www3.cde.ca.gov/demo-downloads/attendance/chronicabsenteeism25.txt"

# Getting the txt file info
r = requests.get(url)
r.raise_for_status()
text = r.content.decode("cp1252", errors="replace")  # or "latin-1"

# %%
# Converting the text into pandas df
df = pd.read_csv(StringIO(text), sep="\t")
df.columns = df.columns.str.strip()

# %%
# Filtering the DataFrame to only show school-level data for grades 9-12 (high school) and removing all District Office locations (school code == 0.0)
# Also cleaning up the columns to keep only those we want
df = df[(df['Aggregate Level'] == 'S') & (df['Reporting Category'] == 'GR912') & (df['School Code'] != 0.0)]
df = df.drop(columns = [col for col in df.columns if col in ['Academic Year', 'Aggregate Level', 'County Name', 'District Name', 'School Name', 'Reporting Category']])
df = df.reset_index()

# %%
df
# Out:
#        index  County Code  District Code  School Code Charter School DASS  \
# 0     134361            1        10017.0     112607.0            Yes  No
# 1     134464            1        10017.0     136101.0            Yes  No
# 2     134568            1        10017.0     130401.0            No   Yes
# 3     134588            1        10017.0     130419.0            No   Yes
# 4     134607            1        10017.0     130625.0            Yes  Yes
# ...      ...          ...            ...          ...            ...  ...
# 2672  340553           58        72736.0    5835202.0            No   No
# 2673  340915           58        72736.0    5830096.0            No   Yes
# 2674  341074           58        72769.0    5838305.0            No   No
# 2675  341095           58        72769.0     123570.0            No   Yes
# 2676  341113           58        72769.0     133751.0            No   Yes
#
#      ChronicAbsenteeismEligibleCumulativeEnrollment ChronicAbsenteeismCount  \
# 0                                               154                      90
# 1                                               174                       0
# 2                                                86                      15
# 3                                               107                      94
# 4                                               116                      20
# ...                                             ...                     ...
# 2672                                           1077                     220
# 2673                                            343                     213
# 2674                                           1118                     169
# 2675                                             22                      16
# 2676                                             65                      52
#
#      ChronicAbsenteeismRate
# 0                      58.4
# 1                       0.0
# 2                      17.4
# 3                      87.9
# 4                      17.2
# ...                     ...
# 2672                   20.4
# 2673                   62.1
# 2674                   15.1
# 2675                   72.7
# 2676                   80.0
#
# [2677 rows x 9 columns]

# %%
df['School Code'].nunique()
# Out:
# 2677
